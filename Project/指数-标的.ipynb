# %% [markdown]
# # 指数标的
#
# - 作者：DGC'Idea
# - 版本：V0.3
# - 更新日期：2018年2月4日
#
# ----------
#
# - 指数范围：沪深规模指数、行业指数、主题指数，恒生指数、恒生国企指数；
# - 指数成立10年以上的，只用最近十年的数据(港股十五年)，指数成立不满三年的，剔除；
# - 采用等权PE指标，根据PE的分位点给出指数的量化估值状态；
# - 采用指数PE的统计值（最小、最大、中位数等）及指数的波动率、股息率、回报率作为辅助进行量化估值；
# - 使用上证指数、深成指数、中证流通、中证全指作为辅助对全市场进行量化估值。

# %%
#导入库
import numpy as np
import pandas as pd

#引入自定义库
import sys
sys.path.append('/home/jquser')
from pf_idx import Index

# index=Index('idx_data','../Data/')
index=Index('csv','../Data/')
# Out:
# 数据引擎：运行于研究
# 指数框架：运行于研究

# %% [markdown]
# ## 1.指数标的

# %%
#沪深指数列表
index_pool=[
    #'code','name','market','type','watch','fund'
    #A股大盘指数
    ['000902',u'全市场','sh','qsc',True,None],
    ['399106',u'深证综指','sz','qsc',True,None], 
    ['000001',u'上证综指','sh','qsc',False,None],
    ['000985',u'中证全指','sh','qsc',False,None],
    ['399101',u'中小板综','sz','qsc',False,None],
    ['399102',u'创业板综','sz','qsc',False,None],
    #A股规模指数
    ['000016',u'上证50','sh','kj',True,None],
    ['000010',u'上证180','sh','kj',True,None],
    ['000300',u'沪深300','sh','kj',True,None],
    ['000905',u'中证500','sh','kj',True,None], 
    ['000852',u'中证1000','sh','kj',True,None],   
    ['399330',u'深证100','sz','kj',True,None],     
    ['399006',u'创业板指','sz','kj',True,None],
    ['399005',u'中小板指','sz','kj',True,None],  
    ['000009',u'上证380','sh','kj',False,None],
    ['000903',u'中证100','sh','kj',False,None],
    ['000904',u'中证200','sh','kj',False,None],
    ['000906',u'中证800','sh','kj',False,None], 
    ['399001',u'深证成指','sz','kj',False,None],
    ['399673',u'创业板50','sz','kj',False,None],
    #A股窄基指数
    ['000991',u'全指医药','sh','zj',True,None],
    ['000992',u'全指金融','sh','zj',True,None],
    ['000990',u'全指消费','sh','zj',True,None],
    ['000993',u'全指信息','sh','zj',True,None], 
    ['000807',u'食品饮料','sh','zj',True,None],
    ['000922',u'中证红利','sh','zj',True,None],
    ['399812',u'中证养老','sz','zj',True,None],
    ['399967',u'中证军工','sz','zj',True,None],
    ['000827',u'中证环保','sh','zj',True,None], 
    ['399971',u'中证传媒','sz','zj',True,None],
    ['000989',u'全指可选','sh','zj',False,None],
    ['000988',u'全指工业','sh','zj',False,None],
    ['000986',u'全指能源','sh','zj',False,None],  
    ['000931',u'中证可选','sh','zj',False,None],       
    ['000015',u'红利指数','sh','zj',False,None],
    ['000068',u'上证资源','sh','zj',False,None],    
    ['000998',u'中证TMT','sh','zj',False,None],
    ['000978',u'医药100','sh','zj',False,None],
    ['399989',u'中证医疗','sz','zj',False,None],
    ['399986',u'中证银行','sz','zj',False,None],
    ['399814',u'中证大农业','sz','zj',False,None],
    ['399975',u'全指证券','sz','zj',True,None],       
    ['399324',u'深证红利','sz','zj',False,None],   
    ['399976',u'新能源汽车','sz','zj',False,None],
    ['399808',u'中证新能源','sz','zj',False,None],
    ['399806',u'环境治理','sz','zj',False,None],
    ['000925',u'基本面50','sh','zj',False,None],
    ['399550',u'央视50','sz','zj',False,None],
    ['000977',u'内地低碳','sh','zj',False,None],
    ['000841',u'800医药','sh','zj',False,None],
    ['399624',u'中创400','sz','zj',False,None],
    ['399811',u'申万电子','sz','zj',False,None],
    ['399396',u'国证食品','sz','zj',False,None],
    ['000932',u'中证消费','sh','zj',True,None],
    ['399997',u'中证白酒','sz','zj',False,None],
    # 港股指数   
    ['HSI',u'恒生指数','hk','',True,None],
    ['HSCEI',u'恒生国企','hk','',True,None],
    # 美股指数      
    ['SPX',u'标普500','us','',True,None],
    ['DJIA',u'道琼斯','us','',False,None],    
    ['NDAQ',u'纳斯达克','us','',False,None],  
    # 欧洲 
    ['GDAXI',u'德国DAX30','eu','',False,None],      
    ['FTSE',u'英国富时100','eu','',False,None],  
    ['FCHI',u'法国CAC40','eu','',False,None],  
    ['SX5E',u'欧洲斯托克50','eu','',False,None],  
    # 亚洲
    ['N225',u'日经225','as','',False,None],  
    # 其它
#     ['VIX',u'VIX波动率','qt','',False,None], 
#     ['BDI',u'波罗的海干散货','qt','',False,None],
#     ['C10Y',u'中国10年期国债','yp','',False,None],
]



#保存指数标的

index.pool.create(index_pool)

# %%
index.pool.show()
# Out:
#                 名称 market type  watch  fund
# 000902.SH      全市场     sh  qsc   True   NaN
# 399106.SZ     深证综指     sz  qsc   True   NaN
# 000001.SH     上证综指     sh  qsc  False   NaN
# 000985.SH     中证全指     sh  qsc  False   NaN
# 399101.SZ     中小板综     sz  qsc  False   NaN
# 399102.SZ     创业板综     sz  qsc  False   NaN
# 000016.SH     上证50     sh   kj   True   NaN
# 000010.SH    上证180     sh   kj   True   NaN
# 000300.SH    沪深300     sh   kj   True   NaN
# 000905.SH    中证500     sh   kj   True   NaN
# 000852.SH   中证1000     sh   kj   True   NaN
# 399330.SZ    深证100     sz   kj   True   NaN
# 399006.SZ     创业板指     sz   kj   True   NaN
# 399005.SZ     中小板指     sz   kj   True   NaN
# 000009.SH    上证380     sh   kj  False   NaN
# 000903.SH    中证100     sh   kj  False   NaN
# 000904.SH    中证200     sh   kj  False   NaN
# 000906.SH    中证800     sh   kj  False   NaN
# 399001.SZ     深证成指     sz   kj  False   NaN
# 399673.SZ    创业板50     sz   kj  False   NaN
# ...

# %%
#沪深指数列表
index_pool={
    #A股大盘指数
    '000902':{'name':u'全市场','market':'sh','type':'qsc','use':True,'fund':[None]},
    '399106':{'name':u'深证综指','market':'sz','type':'qsc','use':True,'fund':[None]}, 
    '000001':{'name':u'上证综指','market':'sh','type':'qsc','use':False,'fund':[None]},
    '000985':{'name':u'中证全指','market':'sh','type':'qsc','use':False,'fund':[None]},
    '399101':{'name':u'中小板综','market':'sz','type':'qsc','use':False,'fund':[None]},
    '399102':{'name':u'创业板综','market':'sz','type':'qsc','use':False,'fund':[None]},
    #A股规模指数
    '000016':{'name':u'上证50','market':'sh','type':'kj','use':True,'fund':[None]},
    '000010':{'name':u'上证180','market':'sh','type':'kj','use':True,'fund':[None]},
    '000300':{'name':u'沪深300','market':'sh','type':'kj','use':True,'fund':[None]},
    '000905':{'name':u'中证500','market':'sh','type':'kj','use':True,'fund':[None]}, 
    '000852':{'name':u'中证1000','market':'sh','type':'kj','use':True,'fund':[None]},   
    '399330':{'name':u'深证100','market':'sz','type':'kj','use':True,'fund':[None]},     
    '399006':{'name':u'创业板指','market':'sz','type':'kj','use':True,'fund':[None]},
    '399005':{'name':u'中小板指','market':'sz','type':'kj','use':True,'fund':[None]},  
    '000009':{'name':u'上证380','market':'sh','type':'kj','use':False,'fund':[None]},
    '000903':{'name':u'中证100','market':'sh','type':'kj','use':False,'fund':[None]},
    '000904':{'name':u'中证200','market':'sh','type':'kj','use':False,'fund':[None]},
    '000906':{'name':u'中证800','market':'sh','type':'kj','use':False,'fund':[None]}, 
    '399001':{'name':u'深证成指','market':'sz','type':'kj','use':False,'fund':[None]},
    '399673':{'name':u'创业板50','market':'sz','type':'kj','use':False,'fund':[None]},
    #A股窄基指数
    '000991':{'name':u'全指医药','market':'sh','type':'zj','use':True,'fund':[None]},
    '000992':{'name':u'全指金融','market':'sh','type':'zj','use':True,'fund':[None]},
    '000990':{'name':u'全指消费','market':'sh','type':'zj','use':True,'fund':[None]},
    '000993':{'name':u'全指信息','market':'sh','type':'zj','use':True,'fund':[None]}, 
    '000807':{'name':u'食品饮料','market':'sh','type':'zj','use':True,'fund':[None]},
    '000922':{'name':u'中证红利','market':'sh','type':'zj','use':True,'fund':[None]},
    '399812':{'name':u'中证养老','market':'sz','type':'zj','use':True,'fund':[None]},
    '399967':{'name':u'中证军工','market':'sz','type':'zj','use':True,'fund':[None]},
    '000827':{'name':u'中证环保','market':'sh','type':'zj','use':True,'fund':[None]}, 
    '399971':{'name':u'中证传媒','market':'sz','type':'zj','use':True,'fund':[None]},
    '000989':{'name':u'全指可选','market':'sh','type':'zj','use':False,'fund':[None]},
    '000988':{'name':u'全指工业','market':'sh','type':'zj','use':False,'fund':[None]},
    '000986':{'name':u'全指能源','market':'sh','type':'zj','use':False,'fund':[None]},  
    '000931':{'name':u'中证可选','market':'sh','type':'zj','use':False,'fund':[None]},       
    '000015':{'name':u'红利指数','market':'sh','type':'zj','use':False,'fund':[None]},
    '000068':{'name':u'上证资源','market':'sh','type':'zj','use':False,'fund':[None]},    
    '000998':{'name':u'中证TMT','market':'sh','type':'zj','use':False,'fund':[None]},
    '000978':{'name':u'医药100','market':'sh','type':'zj','use':False,'fund':[None]},
    '399989':{'name':u'中证医疗','market':'sz','type':'zj','use':False,'fund':[None]},
    '399986':{'name':u'中证银行','market':'sz','type':'zj','use':False,'fund':[None]},
    '399814':{'name':u'中证大农业','market':'sz','type':'zj','use':False,'fund':[None]},
    '399975':{'name':u'全指证券','market':'sz','type':'zj','use':False,'fund':[None]},       
    '399324':{'name':u'深证红利','market':'sz','type':'zj','use':False,'fund':[None]},   
    '399976':{'name':u'新能源汽车','market':'sz','type':'zj','use':False,'fund':[None]},
    '399808':{'name':u'中证新能源','market':'sz','type':'zj','use':False,'fund':[None]},
    '399806':{'name':u'环境治理','market':'sz','type':'zj','use':False,'fund':[None]},
    '000925':{'name':u'基本面50','market':'sh','type':'zj','use':False,'fund':[None]},
    '399550':{'name':u'央视50','market':'sz','type':'zj','use':False,'fund':[None]},
    '000977':{'name':u'内地低碳','market':'sh','type':'zj','use':False,'fund':[None]},
    '000841':{'name':u'800医药','market':'sh','type':'zj','use':False,'fund':[None]},
    '399624':{'name':u'中创400','market':'sz','type':'zj','use':False,'fund':[None]},
    '399811':{'name':u'申万电子','market':'sz','type':'zj','use':False,'fund':[None]},
    '399396':{'name':u'国证食品','market':'sz','type':'zj','use':False,'fund':[None]},
    '000932':{'name':u'中证消费','market':'sh','type':'zj','use':False,'fund':[None]},
    '399997':{'name':u'中证白酒','market':'sz','type':'zj','use':False,'fund':[None]},
    #港股指数列表       
    'hscei':{'name':u'恒生国企','market':'hk','type':'','use':True,'fund':[None]},
    'hsi':{'name':u'恒生指数','market':'hk','type':'','use':True,'fund':[None]},
    #美股指数列表       
    'sp500':{'name':u'标普500','market':'us','type':'','use':True,'fund':[None]},
    }



#保存指数标的
# save_index_pool(index_pool,'all')

# %%
index.codes.read('idx_pool')
# Out:
#                name market type  watch  fund
# 000902.XSHG     全市场     sh  qsc   True  None
# 000902.XSHG     全市场     sh  qsc   True  None
# 399106.XSHE    深证综指     sz  qsc   True  None
# 000001.XSHG    上证综指     sh  qsc  False  None
# 000985.XSHG    中证全指     sh  qsc  False  None
# 399101.XSHE    中小板综     sz  qsc  False  None
# 399102.XSHE    创业板综     sz  qsc  False  None
# 000016.XSHG    上证50     sh   kj   True  None
# 000010.XSHG   上证180     sh   kj   True  None
# 000300.XSHG   沪深300     sh   kj   True  None
# 000905.XSHG   中证500     sh   kj   True  None
# 000852.XSHG  中证1000     sh   kj   True  None
# 399330.XSHE   深证100     sz   kj   True  None
# 399006.XSHE    创业板指     sz   kj   True  None
# 399005.XSHE    中小板指     sz   kj   True  None
# 000009.XSHG   上证380     sh   kj  False  None
# 000903.XSHG   中证100     sh   kj  False  None
# 000904.XSHG   中证200     sh   kj  False  None
# 000906.XSHG   中证800     sh   kj  False  None
# 399001.XSHE    深证成指     sz   kj  False  None
# ...

# %%
# Index.codes.hs

# %% [markdown]
# ## 2.关联基金

# %% [markdown]
# ### 2.1.基金列表

# %%
#引入自定义库
import sys
sys.path.append('/home/jquser')
from pf_fnd import Fund

fund=Fund('csv','../Data/','index')


index_fund_list2={  
    '100032':'000922',  # 富国中证红利 / 中证红利
    '159901':'399330',  # 深100ETF / 深证100
    '159902':'399005',  # 中小板 / 中小板指
    '159903':'399001',  # 深成ETF / 深证成指
    '159905':'399324',  # 深红利 / 深证红利
    '159906':'399346',  # 深成长 / 深证成长
    '159907':'399008',  # 中小300 / 中小300
    '159908':'399703',  # 深F200 / 深证F200
    '159909':'399610',  # 深TMT / TMT50
    '159910':'399702',  # 深F120 / 深证F120
    '159911':'399337',  # 民营ETF / 深证民营
    '159912':'399007',  # 深300ETF / 深证300
    '159913':'399348',  # 深价值 / 深证价值
    '159915':'399006',  # 创业板 / 创业板指
    '159916':'399701',  # 深F60 / 深证F60
    '159918':'399624',  # 中创400 / 中创400
    '159919':'000300',  # 300ETF / 沪深300
    '159922':'000905',  # 500ETF / 中证500
    '159923':'000903',  # 100ETF / 中证100
    '159924':'000984',  # 300等权 / 300等权
    '159925':'000300',  # 南方300 / 沪深300
    '159928':'399932',  # 消费ETF / 中证消费
    '159929':'399933',  # 医药ETF / 中证医药
    '159930':'399928',  # 能源ETF / 中证能源
    '159931':'399934',  # 金融ETF / 中证金融
    '159932':'399802',  # 500深ETF / 500深市
    '159933':'000914',  # 金地ETF / 300金融
    '159935':'000905',  # 景顺500 / 中证500
    '159936':'000989',  # 可选消费 / 全指可选
    '159938':'000991',  # 广发医药 / 全指医药
    '159939':'000993',  # 信息技术 / 全指信息
    '159940':'000992',  # 全指金融 / 全指金融
    '159942':'399612',  # 中创100 / 中创100
    '159943':'399001',  # 深证ETF / 深证成指
    '159944':'000987',  # 全指材料 / 全指材料
    '159945':'000986',  # 全指能源 / 全指能源
    '159946':'000990',  # 全指消费 / 全指消费
    '159948':'399006',  # 创业板EF / 创业板指
    '159949':'399673',  # 创业板50 / 创业板50
    '159952':'399006',  # 创业ETF / 创业板指
    '159953':'000988',  # 工业ETF / 全指工业
    '159955':'399006',  # 创业板E / 创业板指
    '159956':'399006',  # 创业板F / 创业板指
    '159957':'399006',  # 创业板HX / 创业板指
    '159958':'399006',  # 创业板ET / 创业板指
    '510010':'000021',  # 治理ETF / 180治理
    '510020':'000980',  # 超大ETF / 中证超大
    '510030':'000029',  # 价值ETF / 180价值
    '510050':'000016',  # 50ETF / 上证50
    '510060':'000042',  # 央企ETF / 上证央企
    '510070':'000049',  # 民企ETF / 上证民企
    '510090':'000048',  # 责任ETF / 责任指数
    '510110':'000063',  # 周期ETF / 上证周期
    '510120':'000064',  # 非周ETF / 非周期
    '510130':'000044',  # 中盘ETF / 上证中盘
    '510150':'000069',  # 消费ETF / 消费80
    '510160':'399901',  # 小康ETF / 小康指数
    '510170':'000066',  # 商品ETF / 上证商品
    '510180':'000010',  # 180ETF / 上证180
    '510190':'000065',  # 龙头ETF / 上证龙头
    '510210':'000001',  # 综指ETF / 上证指数
    '510220':'000046',  # 中小ETF / 上证中小
    '510230':'000018',  # 金融ETF / 180金融
    '510260':'000067',  # 新兴ETF / 上证新兴
    '510270':'000056',  # 国企ETF / 上证国企
    '510280':'000028',  # 成长ETF / 180成长
    '510290':'000009',  # 380ETF / 上证380
    '510300':'000300',  # 300ETF / 沪深300
    '510310':'000300',  # HS300ETF / 沪深300
    '510330':'000300',  # 华夏300 / 沪深300
    '510360':'000300',  # 广发300 / 沪深300
    '510380':'000300',  # 国寿300 / 沪深300
    '510390':'000300',  # 平安300 / 沪深300
    '510410':'000068',  # 资源ETF / 上证资源
    '510420':'000051',  # 180EWETF / 180等权
    '510430':'000050',  # 50等权 / 50等权
    '510440':'000802',  # 500沪市 / 500沪市
    '510500':'000905',  # 500ETF / 中证500
    '510510':'000905',  # 广发500 / 中证500
    '510520':'000905',  # 诺安500 / 中证500
    '510560':'000905',  # 国寿500 / 中证500
    '510580':'000905',  # ZZ500ETF / 中证500
    '510630':'000036',  # 消费行业 / 上证消费
    '510650':'000038',  # 金融行业 / 上证金融
    '510660':'000037',  # 医药行业 / 上证医药
    '510680':'000016',  # 万家50 / 上证50
    '510710':'000016',  # 上50ETF / 上证50
    '510880':'000015',  # 红利ETF / 红利指数
    '512000':'399975',  # 券商ETF / 证券公司
    '512010':'000913',  # 医药ETF / 300医药
    '512100':'000852',  # 1000ETF / 中证1000
    '512120':'000814',  # 医药股基 / 细分医药
    '512230':'000933',  # 景顺医药 / 中证医药
    '512300':'000857',  # 500医药 / 500医药
    '512310':'000856',  # 500工业 / 500工业
    '512330':'000858',  # 500信息 / 500信息
    '512340':'000854',  # 500原料 / 500原料
    '512400':'000819',  # 有色金属 / 有色金属
    '512500':'000905',  # 中证500 / 中证500
    '512510':'000905',  # ETF500 / 中证500
    '512580':'000827',  # 环保ETF / 中证环保
    '512600':'000932',  # 主要消费 / 中证消费
    '512610':'000933',  # 医药卫生 / 中证医药
    '512640':'000934',  # 金融地产 / 中证金融
    '512660':'399967',  # 军工ETF / 中证军工
    '512680':'399967',  # 军工基金 / 中证军工
    '512700':'399986',  # 银行基金 / 中证银行
    '512800':'399986',  # 银行ETF / 中证银行
    '512810':'399967',  # 军工行业 / 中证军工
    '512880':'399975',  # 证券ETF / 证券公司
    '512900':'399975',  # 证券基金 / 证券公司
    '512980':'399971',  # 传媒ETF / 中证传媒
    '160119':'399905',  # 南方500 / 中证 500
    '160223':'399006',  # 创业板基 / 创业板指
    '160225':'399417',  # 新汽车 / 新能源车
    '160415':'399007',  # 华安S300 / 深证300
    '160615':'000300',  # 鹏华300 / 沪深300
    '160616':'399905',  # 鹏华500 / 中证 500
    '160635':'399933',  # 医药基金 / 中证医药
    '160706':'000300',  # 嘉实 300 / 沪深300
    '160716':'399925',  # 嘉实50 / 基本面50
    '160806':'000906',  # 长盛同庆 / 中证800
    '160807':'000300',  # 长盛300 / 沪深300
    '161017':'399905',  # 富国500 / 中证 500
    '161213':'399963',  # 国投消费 / 中证下游
    '161217':'399961',  # 国投资源 / 中证上游
    '161227':'399330',  # 深证100 / 深证100
    '161607':'399313',  # 融通巨潮 / 巨潮100
    '161715':'399979',  # 大宗商品 / 大宗商品
    '161907':'000922',  # 万家红利 / 中证红利
    '162307':'399903',  # 海富100 / 中证100
    '162510':'399101',  # 国安双力 / 中小板综
    '162711':'399905',  # 广发500L / 中证 500
    '163111':'399005',  # 申万中小 / 中小板指
    '163407':'000300',  # 兴全300 / 沪深300
    '163821':'399984',  # 中银300E / 300等权
    '165309':'000300',  # 建信300 / 沪深300
    '165525':'399995',  # 基建工程 / 基建工程
    '165806':'399330',  # 东吴100 / 深证100
    '166007':'000300',  # 中欧300 / 沪深300
    '167901':'000300',  # 华宸300 / 沪深300
    '501019':'399368',  # 军工基金 / 国证军工
    '501020':'399974',  # 国企改 / 国企改革  
    '501030':'399806',  # 环境治理 / 环境治理
    '501031':'399806',  # 环境C / 环境治理
    '150223':'399975',  # 证券A级 / 证券公司
    '150188':'000832',  # 转债优先 / 标普转债
    '150106':'399005',  # 中小A / 中小板指
    '150321':'399998',  # 煤炭A基 / 中证煤炭
    '150123':'399550',  # 建信50A / 央视50
    '150221':'399959',  # 中航军A / 军工指数
    '150022':'399001',  # 深成指A / 深证成指
    '150331':'399805',  # 网金融A / 互联金融
    '150323':'000827',  # 环保A端 / 中证环保
    '502037':'399805',  # 网金A / 互联金融
    '150190':'000827',  # NCF环保A / 中证环保
    '150325':'399807',  # 高铁A端 / 高铁产业
    '150343':'399975',  # 证券A基 / 证券公司
    '150291':'399986',  # 银行A份 / 中证银行
    '150196':'399395',  # 有色A / 国证有色
    '150299':'399986',  # 银行股A / 中证银行
    '150247':'399971',  # 传媒A级 / 中证传媒
    '150303':'399673',  # 创业股A / 创业板50
    '150287':'399440',  # 钢铁A / 国证钢铁
    '150117':'399393',  # 房地产A / 国证地产
    '150301':'399975',  # 证券股A / 证券公司
    '150335':'399967',  # 军工股A / 中证军工
    '150317':'399805',  # E金融A / 互联金融
    '150293':'399807',  # 高铁A级 / 高铁产业
    '150289':'399998',  # 煤炭A级 / 中证煤炭
    '502057':'399989',  # 医疗A / 中证医疗
    '502031':'399807',  # 高铁A / 高铁产业
    '150261':'399989',  # 医疗A / 中证医疗
    '150167':'000300',  # 银华300A / 沪深300
    '150267':'399986',  # 银行A类 / 中证银行
    '150263':'000852',  # 1000A / 中证1000
    '150213':'399958',  # 成长A级 / 创业成长
    '150295':'399974',  # 改革A / 国企改革
    '150104':'000300',  # HS300A / 沪深300
    '150090':'399958',  # 成长A / 创业成长
    '502054':'399975',  # 券商A / 证券公司
    '150211':'399976',  # 新能车A / CS新能车
    '502014':'000853',  # 一带一A / CSSW丝路
    '150130':'399394',  # 医药A / 国证医药
    '150073':'399958',  # 诺安稳健 / 创业成长
    '150152':'399006',  # 创业板A / 创业板指
    '150145':'000828',  # 高贝塔A / 300高贝
    '150053':'399905',  # 泰达500A / 中证 500
    '150135':'399903',  # 国富100A / 中证100
    '150138':'000842',  # 中证800A / 800等权
    '150281':'399934',  # 金融地A / 中证金融
    '502021':'000016',  # 国金50A / 上证50
    '150036':'000300',  # 建信稳健 / 主动基金
    '150265':'399991',  # 一带A / 一带一路
    '502041':'000016',  # 上50A / 上证50
    '502001':'399982',  # 500等权A / 500等权
    '150150':'000823',  # 有色800A / 800有色
    '150327':'399808',  # 新能A级 / 中证新能
    '150094':'000966',  # 泰信400A / 基本400
    '150012':'399903',  # 中证100A / 中证100
    '150157':'000974',  # 金融A / 800金融
    '150028':'399905',  # 中证500A / 中证 500
    '150112':'399330',  # 深100A / 深证100P
    '150049':'399942',  # 消费收益 / 主动基金
    '150283':'000808',  # SW医药A / 医药生物
    '502011':'399975',  # 证券A / 证券公司
    '150227':'399986',  # 银行A / 中证银行
    '150269':'399997',  # 白酒A / 中证白酒
    '150329':'399809',  # 保险A / 保险主题
    '502049':'000016',  # 上证50A / 上证50
    '150233':'399810',  # 传媒业A / CSSW传媒
    '150194':'399970',  # 互联网A / 移动互联
    '150018':'399004',  # 银华稳进 / 深证100R
    '150051':'000300',  # 沪深300A / 沪深300
    '150255':'399986',  # 银行业A / 中证银行
    '150257':'399993',  # 生物A / CSWD生科
    '150171':'399707',  # 证券A / CSSW证券
    '150277':'399807',  # 高铁A / 高铁产业
    '150209':'399974',  # 国企改A / 国企改革
    '150241':'399986',  # 银行A级 / 中证银行
    '150200':'399975',  # 券商A / 证券公司
    '150186':'399967',  # 军工A级 / 中证军工
    '150121':'399918',  # 银河优先 / 300 成长
    '150198':'399396',  # 食品A / 国证食品
    '150225':'399966',  # 证保A级 / 800证保
    '150305':'399812',  # 养老A / 养老产业
    '150064':'399904',  # 同瑞A / 中证 200
    '150055':'399905',  # 500A / 中证 500
    '150083':'399330',  # 深证100A / 深证100P
    '150307':'399804',  # 体育A / 中证体育
    '150203':'399971',  # 传媒A / 中证传媒
    '150205':'399973',  # 国防A / 中证国防
    '150235':'399975',  # 券商A级 / 证券公司
    '150243':'399006',  # 创业A / 创业板指
    '502004':'399967',  # 军工A / 中证军工
    '150032':'399923',  # 多利优先 / 债券总指
    '150249':'399986',  # 银行A端 / 中证银行
    '150271':'399441',  # 生物药A / 生物医药
    '150173':'000998',  # TMT中证A / 中证TMT
    '150181':'399967',  # 军工A / 中证军工
    '150259':'399992',  # 重组A / CSWD并购
    '150057':'399008',  # 中小300A / 中小300P
    '150273':'399991',  # 带路A / 一带一路
    '150311':'399996',  # 智能A / 智能家居
    '150217':'399412',  # 新能源A / 国证新能
    '502007':'399974',  # 国企改A / 国企改革
    '150275':'399991',  # 一带一A / 一带一路
    '150245':'399970',  # 互联A / 移动互联
    '150177':'399966',  # 证保A / 800证保
    '150030':'000971',  # 中证90A / 等权90
    '150143':'000832',  # 转债A级 / 中证转债
    '150100':'000805',  # 资源A / A股资源
    '150076':'000300',  # 浙商稳健 / 沪深300
    '150184':'000827',  # 环保A / 中证环保
    '150092':'399007',  # 诺德300A / 深证300P
    '150315':'399803',  # 工业4A / 工业4.0
    '150164':'000832',  # 可转债A / 中证转债
    '150179':'399935',  # 信息A / 中证信息
    '502027':'399429',  # 新丝路A / 新丝路
    '502017':'399991',  # 带路A / 一带一路
    '150207':'399983',  # 地产A端 / 地产等权
    '150237':'000827',  # 环保A级 / 中证环保
    '502024':'399440',  # 钢铁A / 国证钢铁
    '150309':'399994',  # 信息安A / 信息安全
    '150148':'000841',  # 医药800A / 800医药
    '150231':'399811',  # 电子A / CSSW电子
    '150251':'399990',  # 煤炭A / 煤炭等权
    '150279':'399808',  # 新能A / 中证新能
    '150047':'399942',  # 消费A / 主动基金
    '150229':'399987',  # 酒A / 中证酒
    '150215':'399610',  # TMT A / TMT50
    '150192':'399965',  # 地产A / 800地产
    '150066':'399481',  # 互利A / 中证全债
    '150059':'399944',  # 资源A级 / 内地资源
    '150016':'000300',  # 合润A / 主动基金
    '512070':'000849',      # 非银ETF / 300非银
    '512560':'399967',      # 中证军工 / 中证军工
    '161630':'399814',  # 中证大农业指数 / 融通农业
    '501050':'000016',  # 上证50 / 50AH
    
    #分级基金母基金
    '163109':'399106',  # 深证综指 / 申万菱信深证成指分级证券投资基金
    '502048':'000016',  # 上证50 / 易方达上证50指数分级证券投资基金
    '161022':'399006',  # 创业板指 / 富国创业板指数分级证券投资基金
    '160637':'399006',  # 创业板指 / 鹏华创业板指数分级证券投资基金
    '161118':'399005',  # 中小板指 / 易方达中小板指数分级证券投资基金
    '160626':'000993',  # 全指信息 / 鹏华中证信息技术指数分级证券投资基金
    '163115':'399967',  # 中证军工 / 申万菱信中证军工指数分级证券投资基金
    '502056':'399989',  # 中证医疗指数 / 广发中证医疗指数分级证券投资基金
    '162412':'399989',  # 中证医疗指数 / 华宝兴业中证医疗指数分级证券投资基金
    '163114':'000827',  # 中证环保 / 申万菱信中证环保产业指数分级证券投资基金
    '164304':'000827',  # 中证环保 / 新华中证环保产业指数分级证券投资基金
    '160634':'000827',  # 中证环保 / 鹏华中证环保产业指数分级证券投资基金
    '165522':'000998',  # 中证TMT / 信诚中证TMT产业主题指数分级证券投资基金
    '160631':'399986',  # 中证银行指数 / 鹏华中证银行指数分级证券投资基金
    '502010':'399975',  # 中证全指证券公司指数(四级行业) / 易方达证券公司指数分级证券投资基金
    '161720':'399975',  # 中证全指证券公司指数(四级行业) / 招商中证全指证券公司指数分级证券投资基金
    '161028':'399976',  # 中证新能源汽车指数 / 富国中证新能源汽车指数分级证券投资基金
    '160640':'399808',  # 中证新能源指数 / 鹏华中证新能源指数分级证券投资基金
    '160629':'399971',  # 中证传媒指数 / 鹏华中证传媒指数分级证券投资基金
    '164818':'399971',  # 中证传媒指数 / 工银瑞信中证传媒指数分级证券投资基金
    '165312':'399550',  # 央视50 / 建信央视财经50指数分级发起式证券投资基金
    '163116':'399811',  # 中证申万电子行业投资指数 / 申万菱信中证申万电子行业投资指数分级证券投资基金   
    }

index_fund_fjm={
    '163109':'399106',  # 深证综指 / 申万菱信深证成指分级证券投资基金
    '502048':'000016',  # 上证50 / 易方达上证50指数分级证券投资基金
    '161022':'399006',  # 创业板指 / 富国创业板指数分级证券投资基金
    '160637':'399006',  # 创业板指 / 鹏华创业板指数分级证券投资基金
    '161118':'399005',  # 中小板指 / 易方达中小板指数分级证券投资基金
    '160626':'000993',  # 全指信息 / 鹏华中证信息技术指数分级证券投资基金
    '163115':'399967',  # 中证军工 / 申万菱信中证军工指数分级证券投资基金
    '502056':'399989',  # 中证医疗指数 / 广发中证医疗指数分级证券投资基金
    '162412':'399989',  # 中证医疗指数 / 华宝兴业中证医疗指数分级证券投资基金
    '163114':'000827',  # 中证环保 / 申万菱信中证环保产业指数分级证券投资基金
    '164304':'000827',  # 中证环保 / 新华中证环保产业指数分级证券投资基金
    '160634':'000827',  # 中证环保 / 鹏华中证环保产业指数分级证券投资基金
    '165522':'000998',  # 中证TMT / 信诚中证TMT产业主题指数分级证券投资基金
    '160631':'399986',  # 中证银行指数 / 鹏华中证银行指数分级证券投资基金
    '502010':'399975',  # 中证全指证券公司指数(四级行业) / 易方达证券公司指数分级证券投资基金
    '161720':'399975',  # 中证全指证券公司指数(四级行业) / 招商中证全指证券公司指数分级证券投资基金
    '161028':'399976',  # 中证新能源汽车指数 / 富国中证新能源汽车指数分级证券投资基金
    '160640':'399808',  # 中证新能源指数 / 鹏华中证新能源指数分级证券投资基金
    '160629':'399971',  # 中证传媒指数 / 鹏华中证传媒指数分级证券投资基金
    '164818':'399971',  # 中证传媒指数 / 工银瑞信中证传媒指数分级证券投资基金
    '165312':'399550',  # 央视50 / 建信央视财经50指数分级发起式证券投资基金
    '163116':'399811',  # 中证申万电子行业投资指数 / 申万菱信中证申万电子行业投资指数分级证券投资基金  
    }

index_fund_bad={
    '159951':'399422',  # 中关村A / 中关村A    
    
    '150219':'H30344',  # 健康A / 健康产业
    '150297':'H30535',  # 互联A级 / 互联网
    
    '501002':'930659',  # 能源互联 / CS能源互
    '501005':'930719',  # 精准医疗 / CS精准医
    '501007':'930720',  # 互联医疗 / CS互医疗
    '501008':'930720',  # 互联医C / CS互医疗
    '501009':'930743',  # 生物科技 / 中证生科
    '501010':'930743',  # 生物科C / 中证生科
    '501011':'930641',  # 中药基金 / 中证中药
    '501012':'930641',  # 中药C / 中证中药
    '501023':'930746',  # 港中小企 / 港中小企
    '161631':'930713',  # 人工智能 / CS人工智
    '161033':'930721',  # 智能汽车 / CS智汽车
    '161035':'930791',  # 医药增强 / 中证医药
    '163119':'930629',  # 申万健康 / CSSW健康 
    
    '510810':'-',       # 上海国企 / 上海国企
    '511220':'-',      # 城投ETF / 沪质城投
    '512200':'-',      # 房地产 / 房地产
    '512210':'-',      # 景顺食品 / 中证800食品
    '512220':'-',      # 景顺TMT / TMT150
    '511260':'-',      # 十年国债 / 10年国债
    '511010':'000140',  # 国债ETF / 5年国债
    
    '150169':'HSI',     # 恒生A / 恒生指数
    '513600':'HSI',  # 恒指ETF / 恒生指数
    '513660':'HSI',  # 恒生通 / 恒生指数
    '159920':'HSI',  # 恒生ETF / 恒生指数
    '159954':'HSCEI',  # H股ETF / 恒生国企
    '510900':'HSCEI',   # H股ETF / 恒生国企
    '150175':'HSCEI',   # H股A / 恒生国企
    '161124':'HSHKSI',  # 香港小盘 / 恒生小型股
    '160922':'HSMSI',  # 恒生中小 / 恒生中小型股
    
    '501029':'CSPSADRP',   # 红利基金 / 标普A股红利
    '501021':'SPHCMSHP',   # 香港中小 / 香港中小
}

index_fund_list={ 
    #etf
    '510170.XSHG':'000066.XSHG',    # etf    商品ETF    上证商品
    '510660.XSHG':'000037.XSHG',    # etf    医药行业    上证医药
    '512310.XSHG':'000856.XSHG',    # etf    500工业    500工业
    '512000.XSHG':'399975.XSHE',    # etf    券商ETF    中证全指证券公司指数(四级行业)
    '510270.XSHG':'000056.XSHG',    # etf    国企ETF    上证国企
    '510330.XSHG':'000300.XSHG',    # etf    华夏300    沪深300
    '510060.XSHG':'000042.XSHG',    # etf    央企ETF    上证央企
    '512640.XSHG':'000934.XSHG',    # etf    金融地产    中证金融
    '510560.XSHG':'000905.XSHG',    # etf    国寿500    中证500
    '510360.XSHG':'000300.XSHG',    # etf    广发300    沪深300
    '512980.XSHG':'399971.XSHE',    # etf    传媒ETF    中证传媒指数
    '512010.XSHG':'000913.XSHG',    # etf    医药ETF    300医药
    '510430.XSHG':'000050.XSHG',    # etf    50等权    50等权
    '512580.XSHG':'000827.XSHG',    # etf    环保ETF    中证环保
    '510070.XSHG':'000049.XSHG',    # etf    民企ETF    上证民企
    '512900.XSHG':'399975.XSHE',    # etf    证券基金    中证全指证券公司指数(四级行业)
    '512330.XSHG':'000858.XSHG',    # etf    500信息    500信息
    '510300.XSHG':'000300.XSHG',    # etf    300ETF    沪深300
    '159908.XSHE':'399703.XSHE',    # etf    深F200    深证F200
    '159909.XSHE':'399610.XSHE',    # etf    深TMT    TMT50
    '159906.XSHE':'399346.XSHE',    # etf    深成长    深证成长
    '159907.XSHE':'399008.XSHE',    # etf    中小300    中小300
    '510190.XSHG':'000065.XSHG',    # etf    龙头ETF    上证龙头
    '159905.XSHE':'399324.XSHE',    # etf    深红利    深证红利
    '159902.XSHE':'399005.XSHE',    # etf    中小板    中小板指
    '159903.XSHE':'399001.XSHE',    # etf    深成ETF    深证成指
    '159901.XSHE':'399330.XSHE',    # etf    深100ETF    深证100
    '510680.XSHG':'000016.XSHG',    # etf    万家50    上证50
    '512120.XSHG':'000814.XSHG',    # etf    医药股基    细分医药
    '512700.XSHG':'399986.XSHE',    # etf    银行基金    中证银行指数
    '510280.XSHG':'000028.XSHG',    # etf    成长ETF    180成长
    '510160.XSHG':'399901.XSHE',    # etf    小康ETF    中证南方小康产业指数
    '512230.XSHG':'000933.XSHG',    # etf    景顺医药    中证医药
    '510220.XSHG':'000046.XSHG',    # etf    中小ETF    上证中小
    '512600.XSHG':'000932.XSHG',    # etf    主要消费    中证消费
    '510580.XSHG':'000905.XSHG',    # etf    ZZ500ETF    中证500
    '510020.XSHG':'000980.XSHG',    # etf    超大ETF    中证超大
    '512680.XSHG':'399967.XSHE',    # etf    军工基金    中证军工
    '159919.XSHE':'000300.XSHG',    # etf    300ETF    沪深300
    '159918.XSHE':'399624.XSHE',    # etf    中创400    中创400
    '159915.XSHE':'399006.XSHE',    # etf    创业板    创业板指
    '510180.XSHG':'000010.XSHG',    # etf    180ETF    上证180
    '159916.XSHE':'399701.XSHE',    # etf    深F60    深证F60
    '159911.XSHE':'399337.XSHE',    # etf    民营ETF    深证民营
    '159910.XSHE':'399702.XSHE',    # etf    深F120    深证F120
    '159913.XSHE':'399348.XSHE',    # etf    深价值    深证价值
    '159912.XSHE':'399007.XSHE',    # etf    深300ETF    深证300
    '512880.XSHG':'399975.XSHE',    # etf    证券ETF    中证全指证券公司指数(四级行业)
    '510290.XSHG':'000009.XSHG',    # etf    380ETF    上证380
    '510110.XSHG':'000063.XSHG',    # etf    周期ETF    上证周期
    '512800.XSHG':'399986.XSHE',    # etf    银行ETF    中证银行指数
    '510050.XSHG':'000016.XSHG',    # etf    50ETF    上证50
    '510500.XSHG':'000905.XSHG',    # etf    500ETF    中证500
    '510420.XSHG':'000051.XSHG',    # etf    180EWETF    180等权
    '510230.XSHG':'000018.XSHG',    # etf    金融ETF    180金融
    '512510.XSHG':'000905.XSHG',    # etf    ETF500    中证500
    '510030.XSHG':'000029.XSHG',    # etf    价值ETF    180价值
    '159928.XSHE':'399932.XSHE',    # etf    消费ETF    中证主要消费指数
    '159929.XSHE':'399933.XSHE',    # etf    医药ETF    中证医药卫生指数
    '510310.XSHG':'000300.XSHG',    # etf    HS300ETF    沪深300
    '159922.XSHE':'000905.XSHG',    # etf    500ETF    中证500
    '159923.XSHE':'000903.XSHG',    # etf    100ETF    中证100
    '159924.XSHE':'000984.XSHG',    # etf    300等权    300等权
    '159925.XSHE':'000300.XSHG',    # etf    南方300    沪深300
    '512100.XSHG':'000852.XSHG',    # etf    1000ETF    中证1000指数
    '512810.XSHG':'399967.XSHE',    # etf    军工行业    中证军工
    '159936.XSHE':'000989.XSHG',    # etf    可选消费    全指可选
    '159935.XSHE':'000905.XSHG',    # etf    景顺500    中证500
    '512500.XSHG':'000905.XSHG',    # etf    中证500    中证500
    '159933.XSHE':'000914.XSHG',    # etf    金地ETF    300金融
    '159932.XSHE':'399802.XSHE',    # etf    500深ETF    500深市
    '159931.XSHE':'399934.XSHE',    # etf    金融ETF    中证金融地产指数
    '159930.XSHE':'399928.XSHE',    # etf    能源ETF    中证能源指数
    '159939.XSHE':'000993.XSHG',    # etf    信息技术    全指信息
    '159938.XSHE':'000991.XSHG',    # etf    广发医药    全指医药
    '512340.XSHG':'000854.XSHG',    # etf    500原料    500原料
    '510520.XSHG':'000905.XSHG',    # etf    诺安500    中证500
    '512610.XSHG':'000933.XSHG',    # etf    医药卫生    中证医药
    '510130.XSHG':'000044.XSHG',    # etf    中盘ETF    上证中盘
    '159942.XSHE':'399612.XSHE',    # etf    中创100    中创100
    '159943.XSHE':'399001.XSHE',    # etf    深证ETF    深证成指
    '159940.XSHE':'000992.XSHG',    # etf    全指金融    全指金融
    '159946.XSHE':'000990.XSHG',    # etf    全指消费    全指消费
    '510510.XSHG':'000905.XSHG',    # etf    广发500    中证500
    '159944.XSHE':'000987.XSHG',    # etf    全指材料    全指材料
    '159945.XSHE':'000986.XSHG',    # etf    全指能源    全指能源
    '159948.XSHE':'399006.XSHE',    # etf    创业板EF    创业板指
    '159949.XSHE':'399673.XSHE',    # etf    创业板50    创业板50
    '510150.XSHG':'000069.XSHG',    # etf    消费ETF    消费80
    '510440.XSHG':'000802.XSHG',    # etf    500沪市    500沪市
    '510210.XSHG':'000001.XSHG',    # etf    综指ETF    上证指数
    '510880.XSHG':'000015.XSHG',    # etf    红利ETF    红利指数
    '510090.XSHG':'000048.XSHG',    # etf    责任ETF    责任指数
    '510630.XSHG':'000036.XSHG',    # etf    消费行业    上证消费
    '512660.XSHG':'399967.XSHE',    # etf    军工ETF    中证军工
    '510120.XSHG':'000064.XSHG',    # etf    非周ETF    非周期
    '510650.XSHG':'000038.XSHG',    # etf    金融行业    上证金融
    '159953.XSHE':'000988.XSHG',    # etf    工业ETF    全指工业
    '159952.XSHE':'399006.XSHE',    # etf    创业ETF    创业板指
    '159955.XSHE':'399006.XSHE',    # etf    创业板E    创业板指
    '159957.XSHE':'399006.XSHE',    # etf    创业板HX    创业板指
    '159958.XSHE':'399006.XSHE',    # etf    创业板ET    创业板指
    '510410.XSHG':'000068.XSHG',    # etf    资源ETF    上证资源
    '510260.XSHG':'000067.XSHG',    # etf    新兴ETF    上证新兴
    '510710.XSHG':'000016.XSHG',    # etf    上50ETF    上证50
    '512070.XSHG':'000849.XSHG',    # etf    非银ETF    沪深300非银行金融指数
    '510010.XSHG':'000021.XSHG',    # etf    治理ETF    180治理
    '512300.XSHG':'000857.XSHG',    # etf    500医药    500医药
    #lof
    '160119.XSHE':'399905.XSHE',    # lof    南方500    中证500
    '160615.XSHE':'000300.XSHG',    # lof    鹏华300    沪深300
    '501050.XSHG':'000016.XSHG',    # lof    50AH    上证50
    '510380.XSHG':'000300.XSHG',    # lof    国寿300    沪深300
    '162711.XSHE':'399905.XSHE',    # lof    广发500L    中证500
    '161630.XSHE':'399814.XSHE',    # lof    融通农业    中证大农业指数
    '162307.XSHE':'399903.XSHE',    # lof    海富100    中证100指数
    '160616.XSHE':'399905.XSHE',    # lof    鹏华500    中证500
    '160807.XSHE':'000300.XSHG',    # lof    长盛300    沪深300
    '160806.XSHE':'000906.XSHG',    # lof    长盛同庆    中证800
    '166007.XSHE':'000300.XSHG',    # lof    中欧300    沪深300
    '163407.XSHE':'000300.XSHG',    # lof    兴全300    沪深300
    '160223.XSHE':'399006.XSHE',    # lof    创业板基    创业板指
    '160635.XSHE':'399933.XSHE',    # lof    医药基金    中证医药卫生指数
    '161217.XSHE':'399961.XSHE',    # lof    国投资源    中证上游资源产业指数
    '161213.XSHE':'399963.XSHE',    # lof    国投消费    中证下游消费与服务产业指数
    '160225.XSHE':'399417.XSHE',    # lof    新汽车    国证新能源汽车指数
    '501030.XSHG':'399806.XSHE',    # lof    环境治理    中证环境治理指数
    '161227.XSHE':'399330.XSHE',    # lof    深证100    深证100
    '165806.XSHE':'399330.XSHE',    # lof    东吴100    深证100
    '161907.XSHE':'000922.XSHG',    # lof    万家红利    中证红利
    '501019.XSHG':'399368.XSHE',    # lof    军工基金    国证军工
    '165525.XSHE':'399995.XSHE',    # lof    基建工程    中证基建工程指数
    '167901.XSHE':'000300.XSHG',    # lof    华宸300    沪深300
    '501020.XSHG':'399974.XSHE',    # lof    国企改    中证国有企业改革指数
    '163821.XSHE':'399984.XSHE',    # lof    中银300E    沪深300等权重指数
    '160706.XSHE':'000300.XSHG',    # lof    嘉实300    沪深300
    '161017.XSHE':'399905.XSHE',    # lof    富国500    中证500
    '165309.XSHE':'000300.XSHG',    # lof    建信300    沪深300
    '161607.XSHE':'399313.XSHE',    # lof    融通巨潮    巨潮100
    '162510.XSHE':'399101.XSHE',    # lof    国安双力    中小板综
    '159956.XSHE':'399006.XSHE',    # lof    创业板F    创业板指
    '501031.XSHG':'399806.XSHE',    # lof    环境C    中证环境治理指数
    '512560.XSHG':'399967.XSHE',    # lof    中证军工    中证军工
    '512400.XSHG':'000819.XSHG',    # lof    有色金属    有色金属
    '160716.XSHE':'399925.XSHE',    # lof    嘉实50    中证锐联基本面50指数
    '160415.XSHE':'399007.XSHE',    # lof    华安S300    深证300
    '510390.XSHG':'000300.XSHG',    # lof    平安300    沪深300
    #场外基金
    '100032.OF'  :'000922.XSHG',    # 场外    富国中证红利 / 中证红利
    }

index_fund_fj={    
    #fja
    '150145.XSHE':'000828.XSHG',    # fja    高贝塔A    300高贝
    '150259.XSHE':'399992.XSHE',    # fja    重组A    中证万得并购重组指数
    '150016.XSHE':'000300.XSHG',    # fja    合润A    沪深300
    '150143.XSHE':'000832.XSHG',    # fja    转债A级    中证转债
    '150150.XSHE':'000823.XSHG',    # fja    有色800A    中证800有色金属指数
    '150275.XSHE':'399991.XSHE',    # fja    一带一A    中证一带一路主题指数
    '150257.XSHE':'399993.XSHE',    # fja    生物A    中证万得生物科技指数
    '502031.XSHG':'399807.XSHE',    # fja    高铁A    中证高铁产业指数
    '502037.XSHG':'399805.XSHE',    # fja    网金A    中证互联网金融指数
    '150064.XSHE':'399904.XSHE',    # fja    同瑞A    中证中盘200指数
    '150094.XSHE':'000966.XSHG',    # fja    泰信400A    基本400
    '150047.XSHE':'399942.XSHE',    # fja    消费A    中证内地消费主题指数
    '150022.XSHE':'399001.XSHE',    # fja    深成指A    深证成指
    '502024.XSHG':'399440.XSHE',    # fja    钢铁A    国证黑色金属行业指数
    '150092.XSHE':'399007.XSHE',    # fja    诺德300A    深证300
    '150090.XSHE':'399958.XSHE',    # fja    成长A    中证创业成长指数
    '150309.XSHE':'399994.XSHE',    # fja    信息安A    中证信息安全主题指数
    '150247.XSHE':'399971.XSHE',    # fja    传媒A级    中证传媒指数
    '150321.XSHE':'399998.XSHE',    # fja    煤炭A基    中证煤炭指数
    '150255.XSHE':'399986.XSHE',    # fja    银行业A    中证银行指数
    '150325.XSHE':'399807.XSHE',    # fja    高铁A端    中证高铁产业指数
    '150327.XSHE':'399808.XSHE',    # fja    新能A级    中证新能源指数
    '150329.XSHE':'399809.XSHE',    # fja    保险A    中证方正富邦保险主题指数
    '150130.XSHE':'399394.XSHE',    # fja    医药A    国证医药
    '150269.XSHE':'399997.XSHE',    # fja    白酒A    中证白酒指数
    '150051.XSHE':'000300.XSHG',    # fja    沪深300A    沪深300
    '150177.XSHE':'399966.XSHE',    # fja    证保A    800非银
    '502021.XSHG':'000016.XSHG',    # fja    国金50A    上证50
    '150261.XSHE':'399989.XSHE',    # fja    医疗A    中证医疗指数
    '150293.XSHE':'399807.XSHE',    # fja    高铁A级    中证高铁产业指数
    '150263.XSHE':'000852.XSHG',    # fja    1000A    中证1000指数
    '150265.XSHE':'399991.XSHE',    # fja    一带A    中证一带一路主题指数
    '502027.XSHG':'399429.XSHE',    # fja    新丝路A    新丝路指数
    '150267.XSHE':'399986.XSHE',    # fja    银行A类    中证银行指数
    '150299.XSHE':'399986.XSHE',    # fja    银行股A    中证银行指数
    '150186.XSHE':'399967.XSHE',    # fja    军工A级    中证军工
    '150251.XSHE':'399990.XSHE',    # fja    煤炭A    中证煤炭等权指数
    '150104.XSHE':'000300.XSHG',    # fja    HS300A    沪深300
    '150315.XSHE':'399803.XSHE',    # fja    工业4A    中证工业4.0指数
    '150317.XSHE':'399805.XSHE',    # fja    E金融A    中证互联网金融指数
    '150311.XSHE':'399996.XSHE',    # fja    智能A    中证智能家居指数
    '150157.XSHE':'000974.XSHG',    # fja    金融A    中证800金融指数
    '150167.XSHE':'000300.XSHG',    # fja    银华300A    沪深300
    '150164.XSHE':'000832.XSHG',    # fja    可转债A    中证转债
    '150295.XSHE':'399974.XSHE',    # fja    改革A    中证国有企业改革指数
    '150018.XSHE':'399004.XSHE',    # fja    银华稳进    深证100R
    '502049.XSHG':'000016.XSHG',    # fja    上证50A    上证50
    '502001.XSHG':'399982.XSHE',    # fja    500等权A    中证500等权重指数
    '150303.XSHE':'399673.XSHE',    # fja    创业股A    创业板50
    '150301.XSHE':'399975.XSHE',    # fja    证券股A    中证全指证券公司指数(四级行业)
    '150307.XSHE':'399804.XSHE',    # fja    体育A    中证体育产业指数
    '150305.XSHE':'399812.XSHE',    # fja    养老A    中证养老产业指数
    '150249.XSHE':'399986.XSHE',    # fja    银行A端    中证银行指数
    '150117.XSHE':'399393.XSHE',    # fja    房地产A    国证地产
    '150289.XSHE':'399998.XSHE',    # fja    煤炭A级    中证煤炭指数
    '502014.XSHG':'000853.XSHG',    # fja    一带一A    中证申万一带一路主题投资指数
    '502017.XSHG':'399991.XSHE',    # fja    带路A    中证一带一路主题指数
    '150273.XSHE':'399991.XSHE',    # fja    带路A    中证一带一路主题指数
    '502011.XSHG':'399975.XSHE',    # fja    证券A    中证全指证券公司指数(四级行业)
    '502054.XSHG':'399975.XSHE',    # fja    券商A    中证全指证券公司指数(四级行业)
    '150049.XSHE':'399942.XSHE',    # fja    消费收益    中证内地消费主题指数
    '150279.XSHE':'399808.XSHE',    # fja    新能A    中证新能源指数
    '150100.XSHE':'000805.XSHG',    # fja    资源A    A股资源
    '150028.XSHE':'399905.XSHE',    # fja    中证500A    中证500
    '150106.XSHE':'399005.XSHE',    # fja    中小A    中小板指
    '150283.XSHE':'000808.XSHG',    # fja    SW医药A    医药生物
    '150291.XSHE':'399986.XSHE',    # fja    银行A份    中证银行指数
    '150059.XSHE':'399944.XSHE',    # fja    资源A级    中证内地资源主题指数
    '150192.XSHE':'399965.XSHE',    # fja    地产A    800地产
    '150190.XSHE':'000827.XSHG',    # fja    NCF环保A    中证环保
    '150281.XSHE':'399934.XSHE',    # fja    金融地A    中证金融地产指数
    '150196.XSHE':'399395.XSHE',    # fja    有色A    国证有色
    '150194.XSHE':'399970.XSHE',    # fja    互联网A    中证移动互联网指数
    '150198.XSHE':'399396.XSHE',    # fja    食品A    国证食品
    '150323.XSHE':'000827.XSHG',    # fja    环保A端    中证环保
    '150287.XSHE':'399440.XSHE',    # fja    钢铁A    国证黑色金属行业指数
    '150053.XSHE':'399905.XSHE',    # fja    泰达500A    中证500
    '150203.XSHE':'399971.XSHE',    # fja    传媒A    中证传媒指数
    '150066.XSHE':'399481.XSHE',    # fja    互利A    企债指数
    '150057.XSHE':'399008.XSHE',    # fja    中小300A    中小300
    '150055.XSHE':'399905.XSHE',    # fja    500A    中证500
    '150205.XSHE':'399973.XSHE',    # fja    国防A    中证国防指数
    '502007.XSHG':'399974.XSHE',    # fja    国企改A    中证国有企业改革指数
    '150209.XSHE':'399974.XSHE',    # fja    国企改A    中证国有企业改革指数
    '150245.XSHE':'399970.XSHE',    # fja    互联A    中证移动互联网指数
    '150207.XSHE':'399983.XSHE',    # fja    地产A端    沪深300地产等权重指数
    '502004.XSHG':'399967.XSHE',    # fja    军工A    中证军工
    '502057.XSHG':'399989.XSHE',    # fja    医疗A    中证医疗指数
    '150030.XSHE':'000971.XSHG',    # fja    中证90A    等权90
    '150181.XSHE':'399967.XSHE',    # fja    军工A    中证军工
    '150184.XSHE':'000827.XSHG',    # fja    环保A    中证环保
    '150335.XSHE':'399967.XSHE',    # fja    军工股A    中证军工
    '150188.XSHE':'000832.XSHG',    # fja    转债优先    中证转债
    '150152.XSHE':'399006.XSHE',    # fja    创业板A    创业板指
    '150211.XSHE':'399976.XSHE',    # fja    新能车A    中证新能源汽车指数
    '150213.XSHE':'399958.XSHE',    # fja    成长A级    中证创业成长指数
    '150215.XSHE':'399610.XSHE',    # fja    TMTA    TMT50
    '150217.XSHE':'399412.XSHE',    # fja    新能源A    国证新能
    '150243.XSHE':'399006.XSHE',    # fja    创业A    创业板指
    '150032.XSHE':'399923.XSHE',    # fja    多利优先    公司债
    '150036.XSHE':'000300.XSHG',    # fja    建信稳健    沪深300
    '150200.XSHE':'399975.XSHE',    # fja    券商A    中证全指证券公司指数(四级行业)
    '150277.XSHE':'399807.XSHE',    # fja    高铁A    中证高铁产业指数
    '150171.XSHE':'399707.XSHE',    # fja    证券A    中证申万证券行业指数
    '150135.XSHE':'399903.XSHE',    # fja    国富100A    中证100指数
    '150343.XSHE':'399975.XSHE',    # fja    证券A基    中证全指证券公司指数(四级行业)
    '150229.XSHE':'399987.XSHE',    # fja    酒A    中证酒指数
    '150179.XSHE':'399935.XSHE',    # fja    信息A    中证信息技术指数
    '150225.XSHE':'399966.XSHE',    # fja    证保A级    800非银
    '150138.XSHE':'000842.XSHG',    # fja    中证800A    800等权
    '150221.XSHE':'399959.XSHE',    # fja    中航军A    军工指数
    '150223.XSHE':'399975.XSHE',    # fja    证券A级    中证全指证券公司指数(四级行业)
    '150271.XSHE':'399441.XSHE',    # fja    生物药A    国证生物医药指数
    '150148.XSHE':'000841.XSHG',    # fja    医药800A    800医药
    '150012.XSHE':'399903.XSHE',    # fja    中证100A    中证100指数
    '502041.XSHG':'000016.XSHG',    # fja    上50A    上证50
    '150241.XSHE':'399986.XSHE',    # fja    银行A级    中证银行指数
    '150076.XSHE':'000300.XSHG',    # fja    浙商稳健    沪深300
    '150112.XSHE':'399330.XSHE',    # fja    深100A    深证100
    '150227.XSHE':'399986.XSHE',    # fja    银行A    中证银行指数
    '150173.XSHE':'000998.XSHG',    # fja    TMT中证A    中证TMT
    '150237.XSHE':'000827.XSHG',    # fja    环保A级    中证环保
    '150123.XSHE':'399550.XSHE',    # fja    建信50A    央视50
    '150073.XSHE':'399958.XSHE',    # fja    诺安稳健    中证创业成长指数
    '150121.XSHE':'399918.XSHE',    # fja    银河优先    沪深300成长指数
    '150331.XSHE':'399805.XSHE',    # fja    网金融A    中证互联网金融指数
    '150233.XSHE':'399810.XSHE',    # fja    传媒业A    中证申万传媒行业投资指数
    '150231.XSHE':'399811.XSHE',    # fja    电子A    中证申万电子行业投资指数
    '150083.XSHE':'399330.XSHE',    # fja    深证100A    深证100
    '150235.XSHE':'399975.XSHE',    # fja    券商A级    中证全指证券公司指数(四级行业)
    #fjm
    '502010.XSHG':'399975.XSHE',    # fjm    易方达证券公司指数分级证券投资基金      中证全指证券公司指数(四级行业)
    '162412.XSHE':'399989.XSHE',    # fjm    华宝兴业中证医疗指数分级证券投资基金    中证医疗指数
    '163115.XSHE':'399967.XSHE',    # fjm    申万菱信中证军工指数分级证券投资基金    中证军工
    '160634.XSHE':'000827.XSHG',    # fjm    鹏华中证环保产业指数分级证券投资基金    中证环保
    '160637.XSHE':'399006.XSHE',    # fjm    鹏华创业板指数分级证券投资基金                     创业板指
    '161715.XSHE':'399979.XSHE',    # fjm    招商中证大宗商品股票指数分级证券投资基金            中证大宗商品股票指数
    '161028.XSHE':'399976.XSHE',    # fjm    富国中证新能源汽车指数分级证券投资基金             中证新能源汽车指数
    '164818.XSHE':'399971.XSHE',    # fjm    工银瑞信中证传媒指数分级证券投资基金               中证传媒指数
    '161022.XSHE':'399006.XSHE',    # fjm    富国创业板指数分级证券投资基金                     创业板指
    '502048.XSHG':'000016.XSHG',    # fjm    易方达上证50指数分级证券投资基金                   上证50
    '160626.XSHE':'000993.XSHG',    # fjm    鹏华中证信息技术指数分级证券投资基金               全指信息
    '502056.XSHG':'399989.XSHE',    # fjm    广发中证医疗指数分级证券投资基金                   中证医疗指数
    '165522.XSHE':'000998.XSHG',    # fjm    信诚中证TMT产业主题指数分级证券投资基金            中证TMT
    '165312.XSHE':'399550.XSHE',    # fjm    建信央视财经50指数分级发起式证券投资基金           央视50
    '163114.XSHE':'000827.XSHG',    # fjm    申万菱信中证环保产业指数分级证券投资基金           中证环保
    '163116.XSHE':'399811.XSHE',    # fjm    申万菱信中证申万电子行业投资指数分级证券投资基金    中证申万电子行业投资指数
    '160640.XSHE':'399808.XSHE',    # fjm    鹏华中证新能源指数分级证券投资基金    中证新能源指数
    '163111.XSHE':'399005.XSHE',    # fjm    申万菱信中小板指数分级证券投资基金    中小板指
    '164304.XSHE':'000827.XSHG',    # fjm    新华中证环保产业指数分级证券投资基金    中证环保
    '163109.XSHE':'399106.XSHE',    # fjm    申万菱信深证成指分级证券投资基金    深证综指
    '160631.XSHE':'399986.XSHE',    # fjm    鹏华中证银行指数分级证券投资基金    中证银行指数
    '160629.XSHE':'399971.XSHE',    # fjm    鹏华中证传媒指数分级证券投资基金    中证传媒指数
    '161720.XSHE':'399975.XSHE',    # fjm    招商中证全指证券公司指数分级证券投资基金    中证全指证券公司指数(四级行业)
    '161118.XSHE':'399005.XSHE',    # fjm    易方达中小板指数分级证券投资基金    中小板指
    }






#保存基金列表
def save_index_fund(file_name,file_root='./'):   
    fund_list=[]    
    for fund_code,index_code in index_fund_list.items():
        #fund_code=code_fund_jq(code)
        #index_code=code_index_jq(name)
        fund=get_security_info(fund_code)
        index=get_security_info(index_code)
        fund_list.append([fund_code,fund.display_name,fund.type,fund.start_date,
                         index_code,index.display_name,index.start_date])


    column_list=['fund_code','fund_name','fund_type','fund_date','index_code','index_name','index_date']    
    df=pd.DataFrame(data=fund_list,columns=column_list) 
    #组织文件名        
    file_path='%sindex_%s_pool.csv'%(file_root,file_name)
    #保存结果
    df.to_csv(file_path) 
    
    
#查看基金列表    
def show_index_fund():
    fund_list=[]    
    for fund_code,index_code in index_fund_list.items():
        #fund_code=code_fund_jq(code1)
        #index_code=code_index_jq(code2)
        fund=get_security_info(fund_code)
        index=get_security_info(index_code)
        fund_list.append([fund_code,fund.display_name,fund.type,fund.start_date,
                         index_code,index.display_name,index.start_date])

    
    column_list=[
        (u'基金', u'代码'), (u'基金', u'名称'), (u'基金', u'类型'), (u'基金', u'成立日期'),
        (u'指数', u'代码'), (u'指数', u'名称'), (u'指数', u'成立日期'), 
        ]   
    df=pd.DataFrame(data=fund_list,columns= pd.MultiIndex.from_tuples(column_list)) 
    return df    
    
# save_index_fund('fund')

fund.pool.create(index_fund_list)
# Out:
# 基金 标的不存在!

# %%
#设置pd显示行列数目
pd.set_option('display.max_rows',500)
fund.pool.show()
# Out:
#                           名称        type start_date  index_code  \
# 510360.SH              广发300         etf  2015-09-09  000300.SH
# 512300.SH              500医药         etf  2015-06-04  000857.SH
# 510170.SH              商品ETF         etf  2011-01-25  000066.SH
# 159952.SZ              创业ETF         etf  2017-05-19  399006.SZ
# 510300.SH             300ETF         etf  2012-05-28  000300.SH
# 510130.SH              中盘ETF         etf  2010-06-23  000044.SH
# 510580.SH           ZZ500ETF         etf  2015-09-14  000905.SH
# 159929.SZ              医药ETF         etf  2013-09-16  399933.SZ
# 512900.SH               证券基金         etf  2017-03-31  399975.SZ
# 160635.SZ               医药基金         lof  2016-08-01  399933.SZ
# 162510.SZ               国安双力         lof  2015-05-20  399101.SZ
# 159940.SZ               全指金融         etf  2015-04-17  000992.SH
# 512680.SH               军工基金         etf  2016-10-14  399967.SZ
# 510430.SH               50等权         etf  2012-09-24  000050.SH
# ...

# %% [markdown]
# ### 2.2.查看基金

# %%
#设置pd显示行列数目
pd.set_option('display.max_rows',500)
df=show_index_fund()
df.sort([(u'基金', u'类型')])
df
# Out:
#               基金                                                      指数  \
#               代码                 名称          类型        成立日期           代码
# 0    510360.XSHG              广发300         etf  2015-09-09  000300.XSHG
# 1    512300.XSHG              500医药         etf  2015-06-04  000857.XSHG
# 2    510170.XSHG              商品ETF         etf  2011-01-25  000066.XSHG
# 3    159952.XSHE              创业ETF         etf  2017-05-19  399006.XSHE
# 4    510300.XSHG             300ETF         etf  2012-05-28  000300.XSHG
# 5    510130.XSHG              中盘ETF         etf  2010-06-23  000044.XSHG
# 6    510580.XSHG           ZZ500ETF         etf  2015-09-14  000905.XSHG
# 7    159929.XSHE              医药ETF         etf  2013-09-16  399933.XSHE
# 8    512900.XSHG               证券基金         etf  2017-03-31  399975.XSHE
# 9    160635.XSHE               医药基金         lof  2016-08-01  399933.XSHE
# 10   162510.XSHE               国安双力         lof  2015-05-20  399101.XSHE
# ...
